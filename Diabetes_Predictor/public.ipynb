# %%
# !pip install fastapi
# !pip install uvicorn
# !pip install pickle5
# !pip install pydantic
# !pip install scikit-learn
# !pip install requests
# !pip install pypi-json
# !pip install pyngrok
# !pip install nest-asyncio
# Out:
# Requirement already satisfied: fastapi in c:\users\yuvra\anaconda3\lib\site-packages (0.116.1)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\yuvra\anaconda3\lib\site-packages (from fastapi) (0.47.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\yuvra\anaconda3\lib\site-packages (from fastapi) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\yuvra\anaconda3\lib\site-packages (from fastapi) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\yuvra\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\yuvra\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\yuvra\anaconda3\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\yuvra\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\yuvra\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.0)
# Requirement already satisfied: uvicorn in c:\users\yuvra\anaconda3\lib\site-packages (0.35.0)
# Requirement already satisfied: click>=7.0 in c:\users\yuvra\anaconda3\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\yuvra\anaconda3\lib\site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: colorama in c:\users\yuvra\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Collecting pickle5
#   Using cached pickle5-0.0.11.tar.gz (132 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py): started
#   Building wheel for pickle5 (setup.py): finished with status 'error'
#   Running setup.py clean for pickle5
# Failed to build pickle5
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-312\pickle5
#       copying pickle5\pickle.py -> build\lib.win-amd64-cpython-312\pickle5
#       copying pickle5\pickletools.py -> build\lib.win-amd64-cpython-312\pickle5
#       copying pickle5\__init__.py -> build\lib.win-amd64-cpython-312\pickle5
#       creating build\lib.win-amd64-cpython-312\pickle5\test
#       copying pickle5\test\pickletester.py -> build\lib.win-amd64-cpython-312\pickle5\test
#       copying pickle5\test\test_pickle.py -> build\lib.win-amd64-cpython-312\pickle5\test
#       copying pickle5\test\test_picklebuffer.py -> build\lib.win-amd64-cpython-312\pickle5\test
#       copying pickle5\test\__init__.py -> build\lib.win-amd64-cpython-312\pickle5\test
#       running build_ext
#       building 'pickle5._pickle' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pickle5
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pickle5)
# Requirement already satisfied: pydantic in c:\users\yuvra\anaconda3\lib\site-packages (2.8.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\yuvra\anaconda3\lib\site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\yuvra\anaconda3\lib\site-packages (from pydantic) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\yuvra\anaconda3\lib\site-packages (from pydantic) (4.11.0)
# Requirement already satisfied: scikit-learn in c:\users\yuvra\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\yuvra\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\yuvra\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yuvra\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\yuvra\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: requests in c:\users\yuvra\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yuvra\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yuvra\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yuvra\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yuvra\anaconda3\lib\site-packages (from requests) (2025.4.26)
# Collecting pypi-json
#   Using cached pypi_json-0.4.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting apeye>=1.1.0 (from pypi-json)
#   Using cached apeye-1.4.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: packaging>=21.0 in c:\users\yuvra\anaconda3\lib\site-packages (from pypi-json) (24.1)
# Requirement already satisfied: requests>=2.26.0 in c:\users\yuvra\anaconda3\lib\site-packages (from pypi-json) (2.32.3)
# Collecting apeye-core>=1.0.0b2 (from apeye>=1.1.0->pypi-json)
#   Using cached apeye_core-1.1.5-py3-none-any.whl.metadata (7.7 kB)
# Collecting domdf-python-tools>=2.6.0 (from apeye>=1.1.0->pypi-json)
#   Using cached domdf_python_tools-3.10.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: platformdirs>=2.3.0 in c:\users\yuvra\anaconda3\lib\site-packages (from apeye>=1.1.0->pypi-json) (3.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yuvra\anaconda3\lib\site-packages (from requests>=2.26.0->pypi-json) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yuvra\anaconda3\lib\site-packages (from requests>=2.26.0->pypi-json) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yuvra\anaconda3\lib\site-packages (from requests>=2.26.0->pypi-json) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yuvra\anaconda3\lib\site-packages (from requests>=2.26.0->pypi-json) (2025.4.26)
# Collecting natsort>=7.0.1 (from domdf-python-tools>=2.6.0->apeye>=1.1.0->pypi-json)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in c:\users\yuvra\anaconda3\lib\site-packages (from domdf-python-tools>=2.6.0->apeye>=1.1.0->pypi-json) (4.11.0)
# Using cached pypi_json-0.4.0-py3-none-any.whl (26 kB)
# Using cached apeye-1.4.1-py3-none-any.whl (107 kB)
# Using cached apeye_core-1.1.5-py3-none-any.whl (99 kB)
# Using cached domdf_python_tools-3.10.0-py3-none-any.whl (126 kB)
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Installing collected packages: natsort, domdf-python-tools, apeye-core, apeye, pypi-json
# Successfully installed apeye-1.4.1 apeye-core-1.1.5 domdf-python-tools-3.10.0 natsort-8.4.0 pypi-json-0.4.0
# Collecting pyngrok
#   Downloading pyngrok-7.2.12-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\yuvra\anaconda3\lib\site-packages (from pyngrok) (6.0.1)
# Downloading pyngrok-7.2.12-py3-none-any.whl (26 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.12
# Requirement already satisfied: nest-asyncio in c:\users\yuvra\anaconda3\lib\site-packages (1.6.0)

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import pickle
import json
import uvicorn
from pyngrok import ngrok
from fastapi.middleware.cors import CORSMiddleware
import nest_asyncio

# %%
app = FastAPI()

# %%
origins = ["*"]

app.add_middleware(
    CORSMiddleware,
    allow_origins=origins,
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

# %%
class model_input(BaseModel):
    
    Pregnancies : int
    Glucose : int
    BloodPressure : int
    SkinThickness : int
    Insulin : int
    BMI : float
    DiabetesPedigreeFunction : float
    Age : int

# %%
diabetes_model = pickle.load(open('diabetes_model.sav', 'rb'))

# %%
@app.post('/diabetes_prediction')
def diabetes_predd(input_parameters : model_input):
    
    input_data = input_parameters.json()
    input_dictionary = json.loads(input_data)
    
    preg = input_dictionary['Pregnancies']
    glu = input_dictionary['Glucose']
    bp = input_dictionary['BloodPressure']
    skin = input_dictionary['SkinThickness']
    insulin = input_dictionary['Insulin']
    bmi = input_dictionary['BMI']
    dpf = input_dictionary['DiabetesPedigreeFunction']
    age = input_dictionary['Age']
    
    
    input_list = [preg, glu, bp, skin, insulin, bmi, dpf, age]
    
    prediction = diabetes_model.predict([input_list])
    
    if (prediction[0] == 0):
        return 'The person is not diabetic'
    else:
        return 'The person is diabetic'

# %%
# Replace 'YOUR_AUTHTOKEN' with your actual ngrok authtoken from https://dashboard.ngrok.com/get-started/your-authtoken
ngrok.set_auth_token('30XnNL5AYC5w5IW3HefU4FXvlDr_75wSCfgF7xy9LYeH3BQqA')
ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)
nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# INFO:     Started server process [10832]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# Public URL: https://fac015de3e7c.ngrok-free.app
